# %%
import pandas as pd
import pyarrow.dataset as ds

dataset = ds.dataset('/home/wsl/data/movies/dailyboxoffice', format='parquet', partitioning="hive")
df = dataset.to_table().to_pandas()

df.to_parquet("~/temp/movie.parquet")

# %%
df.columns
# Out:
# Index(['rnum', 'rank', 'rankInten', 'rankOldAndNew', 'movieCd', 'movieNm',
#        'openDt', 'salesAmt', 'salesShare', 'salesInten', 'salesChange',
#        'salesAcc', 'audiCnt', 'audiInten', 'audiChange', 'audiAcc', 'scrnCnt',
#        'showCnt', 'dt', 'multiMovieYn', 'repNationCd'],
#       dtype='object')

# %%
df
# Out:
#        rnum  rank  rankInten rankOldAndNew   movieCd  \
# 0         1     1          0           OLD  20203702
# 1         2     2          0           OLD  20212866
# 2         3     3          0           OLD  20236146
# 3         4     4          0           OLD  20235735
# 4         5     5          0           OLD  20235596
# ...     ...   ...        ...           ...       ...
# 18295     6     6         -2           OLD  20247430
# 18296     7     7          0           NEW  20241180
# 18297     8     8         -1           OLD  20225184
# 18298     9     9         -1           OLD  20212352
# 18299    10    10          2           OLD  20248129
#
#                                     movieNm      openDt    salesAmt  \
# 0                                노량: 죽음의 바다  2023-12-20  2893509165
# 1                                     서울의 봄  2023-11-22  2666429137
# 2      신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  2023-12-22   565417320
# ...
